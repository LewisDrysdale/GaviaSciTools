# %%
import gst_read_functions as gst
import tkinter
from tkinter import filedialog
import os

## ENTER SENSOR TYPES REQUIRED
# must include 'nav' and 'gps'
types=('nav','gps','missionmanager','autopilot','ecopuck','ctd','aanderaa','sbp') 

## GUI SELECT THE INPUT DIRECTORY (SELECT THE FOLDER ENTITLED 'campaignxxx')
inputpath = filedialog.askdirectory()

logdir=os.path.join(inputpath,'files','log')
savedir=os.path.join(inputpath,'files','processed-log-data')
os.makedirs(savedir, exist_ok=True) 
print('Data are saved at '+savedir)
# Out:
# Data are saved at C:/gavia/controlcenter/db/SD041-KANG-GLAC-GEO-CAPEBOWYER\files\processed-log-data

# %%
gst.gst_unzip_log_data(logdir)
gst.gst_read_log_data(logdir, savedir, types)
# Out:
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
# C:\Users\Marphys\GaviaSciTools\notebooks\..\src\data\gst_sub_functions.py:311: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   nvdf[col]=pd.to_numeric(nvdf[col], errors="ignore",downcast='float')
