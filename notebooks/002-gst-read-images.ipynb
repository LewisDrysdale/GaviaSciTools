# %% [markdown]
# # Read images and creates a video

# %%
import os
sys.path.append('../')
import gst_functions.gst_image_read as gst
imgdir=os.path.join('C:/gavia/controlcenter/db/SDA-trials-2023/files/images')
processedpath=os.path.join('C:/gavia/controlcenter/db/SDA-trials-2023/files/processed-image-data/')
os.makedirs(processedpath, exist_ok=True)  
gst.gst_write_img_to_mp4(imgdir, processedpath)
gst.gst_read_image_metadata(imgdir,processedpath)
# Out:
# file C:/gavia/controlcenter/db/SDA-trials-2023/files/processed-image-data/20230623111413-coords.csv exists already
# file C:/gavia/controlcenter/db/SDA-trials-2023/files/processed-image-data/20230623111535-coords.csv exists already
# file C:/gavia/controlcenter/db/SDA-trials-2023/files/processed-image-data/20230623111709-coords.csv exists already
# file C:/gavia/controlcenter/db/SDA-trials-2023/files/processed-image-data/20230623113420-coords.csv exists already
